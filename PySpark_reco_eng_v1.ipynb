# %% [markdown]
# ## PySpark recommendation engine

# %% [markdown]
# Have noted with Vidyut that currently we have to build method-pool instead of rules. (Notes are in separated email.)
#
# * Here we illustrate the pySpark with ALS and BPR using our own data

# %%
# env
from pyspark import SparkConf, SparkContext 

# methods
from pyspark.mllib.recommendation import ALS, Rating
from bpr_spark.bpr import bprMF

# data processing
import numpy as np
import pandas as pd
# result processing
import heapq

# %% [markdown]
# ## 1. Learning

# %% [markdown]
# ### Load our data

# %% [markdown]
# This fuction translates the data into RDD rating format.

# %%
def get_rating(str):  
    arr = str.split('\t') 
    user_id = int(arr[0])  
    movie_id = int(arr[1])  
    user_rating = float(arr[2])  
    return Rating(user_id, movie_id, user_rating)
try:
    sc.stop()
except:
    pass

# %% [markdown]
# Set Spark Context (cannot be reset once set well).

# %%
conf = SparkConf().setMaster('local').setAppName('RecoEng').set("spark.executor.memory", "8g")  
sc = SparkContext(conf=conf)
data = sc.textFile('/Users/ito/venv/pyspark-rec/CG-Tops/Tops_user-item_data')  
data.top(3)
# Out:
# [u'999\t7071\t1\t736433', u'999\t7070\t1\t736433', u'999\t6951\t1\t736485']

# %%
# because for mllib.recommendation, there is already data structure running on it
ratings = data.map(get_rating) 
ratings.top(3)
# Out:
# [Rating(user=9204, product=43518, rating=1.0),
#  Rating(user=9204, product=43392, rating=2.0),
#  Rating(user=9204, product=43378, rating=1.0)]

# %%
# from sklearn.datasets import load_iris # iris数据集
# from sklearn.model_selection import train_test_split # 分割数据模块
# from sklearn.neighbors import KNeighborsClassifier # K最近邻(kNN，k-NearestNeighbor)分类算法
# from pyspark.ml.tuning import TrainValidationSplit

# # import org.apache.spark.ml.tuning.{ParamGridBuilder, TrainValidationSplit}

# # import pyspark..recommendation import ALS, Rating
# # val data = spark.read.format("libsvm").load("data/mllib/sample_linear_regression_data.txt")
# training__, test__ = ratings.randomSplit([0.9, 0.1], seed = 25)

# %% [markdown]
# ### Collaborative Filtering
# * using Alternating Least Squares (ALS) optimization
# * call java function "trainALSModel"

# %%
split = [0.9, 0.1]
ratings_cf_train, ratings_cf_test = ratings.randomSplit(split, seed = 225)

ratings2 = data.map(lambda line: line.split("\t")).map(lambda x: map(int, x[:2]))
ratings_bpr_train, ratings_bpr_test = ratings2.randomSplit([0.9, 0.1], seed = 25)

# %%
def CollaborativeFiltering(ratings, rank = 10, iterations = 5):
    model = ALS.train(ratings, rank, iterations)
    return model

# %%
# %%time
CFmodel = CollaborativeFiltering(ratings_cf_train,10,5)
# Out:
# CPU times: user 12 ms, sys: 4.51 ms, total: 16.5 ms
# Wall time: 22.1 s

# %%
# %%time
rank = 10  
iterations = 5    
ALSmodel = ALS.train(ratings, rank, iterations)
# Out:
# CPU times: user 12 ms, sys: 4.49 ms, total: 16.5 ms
# Wall time: 20.7 s

# %% [markdown]
# The scalability and efficiency of pySpark is going well, and even it is not CPU-wise multiprocessed. So far so good, means my next step is towards accuracy and realistic level.

# %%
# %%time
CFmodel_ = CollaborativeFiltering(ratings,10,5)
# Out:
# CPU times: user 8.94 ms, sys: 3.67 ms, total: 12.6 ms
# Wall time: 20.8 s

# %%
# sc.stop()

# %% [markdown]
# ### Bayesian Personalized Ranking (for PySpark)
# * optimized using Stochastic Gradient Descent (SGD, cannot be as simply paralled as ALS)
# * have remained only user-item information yet (the basic BPR or say BPR-1)
# * return 2 matrices (user matrix with (#user,k), item matrix with (k,#item))

# %%
# conf = SparkConf().setMaster("local").setAppName("BPR").set("spark.executor.memory", "8g")
# sc = SparkContext(conf=conf)

# %%
# data = sc.textFile("/Users/ito/venv/pyspark-rec/CG-Tops/Tops_user-item_data")
# ratings = data.map(lambda line: line.split("\t")).map(lambda x: map(int, x[:2]))

# %%
# %%time
# bprMF(ratings, rank, num_iter=10, num_neg_samples=30):
userMat, prodMat = bprMF(ratings_bpr_train, 10, 20, 10)
# Out:
# CPU times: user 920 ms, sys: 873 ms, total: 1.79 s
# Wall time: 12min 43s

# %% [markdown]
# ***** Building another version that can run faster (MR for map reduce) (to be continued..)

# %%
# from bpr_spark.distbpr import bpr_MF_MR
# userMat2, prodMat2 = bpr_MF_MR(ratings, 10, 10)
# userMat2, prodMat2 = bpr_MF_MR(ratings, 10, 10, nb_partitions = 8)

# %%
userid = 10
rec_items_bpr = np.inner(userMat[userid].T, prodMat)

# %% [markdown]
# Manually do the similar showcasing like "ALSmodel.recommendProducts(userid, top_howmany)" using heap sorting

# %%
top_howmany = 5
res = []
top_list = heapq.nlargest(top_howmany,rec_items_bpr)
res.append([i for i in range(len(rec_items_bpr)) if rec_items_bpr[i] in top_list])

userid = 10
rec_items = CFmodel.recommendProducts(userid, top_howmany)  

pd.DataFrame(rec_items)
# Out:
#    user  product     rating
# 0    10     5565  43.066266
# 1    10     2560  35.460403
# 2    10    18536  34.197045
# 3    10    18506  31.236967
# 4    10    18508  29.732398

# %% [markdown]
# * Simple result from Collaborative Filtering

# %%
print ('recommend items for userid %d:' % userid)
[i for i in rec_items]
# Out:
# recommend items for userid 10:
# [Rating(user=10, product=5565, rating=43.066266262561186),
#  Rating(user=10, product=2560, rating=35.46040302641053),
#  Rating(user=10, product=18536, rating=34.19704472498653),
#  Rating(user=10, product=18506, rating=31.236967455736426),
#  Rating(user=10, product=18508, rating=29.732397625435627)]

# %% [markdown]
# * Simple result from Bayesian Personalized Ranking

# %%
print ('recommend items for userid %d:' % userid)
for idx, i in enumerate(res[0]):
    print 'user=%d, ' % userid + 'product=%d, ' % i  + 'rating=%f' % top_list[idx]
# Out:
# recommend items for userid 10:
# user=10, product=108, rating=251.157254
# user=10, product=1226, rating=32.101318
# user=10, product=6945, rating=17.967807
# user=10, product=11419, rating=14.482411
# user=10, product=37100, rating=13.816158

# %%
# userMat.shape
# num_users = ratings2.map(lambda x: x[0]).max()

# %%
# %%time

rec_items_cf_ = []
rec_items_bpr_ = []
for i in range(1, 4):
    rec_items_cf_.extend(CFmodel_.recommendProducts(i, top_howmany)) 
    
    rec_items_bpr = np.inner(userMat[i].T, prodMat)
    top_list = heapq.nlargest(top_howmany,rec_items_bpr)
    
    idx = 0
    for j in range(len(rec_items_bpr)):
        if rec_items_bpr[j] in top_list:
            rec_items_bpr_.append((i, j, top_list[idx])) 
            idx += 1
# Out:
# CPU times: user 62.9 ms, sys: 9.53 ms, total: 72.5 ms
# Wall time: 234 ms

# %% [markdown]
# ## 2. Predicting

# %% [markdown]
# ### predicting on test_set for each method considered

# %%
top_howmany = 10

# %% [markdown]
# * Gathering recommending result

# %%
# ## testing
# %%time
# # CFmodel_.recommendProducts(1, top_howmany)
# userid = 10
# rec_items_bpr = np.inner(userMat[userid].T, prodMat)
# res = []
# top_list = heapq.nlargest(top_howmany,rec_items_bpr)
# res.append([i for i in range(len(rec_items_bpr)) if rec_items_bpr[i] in top_list])

# %% [markdown]
# * Blackboxing the recommendProducts from BPR side

# %%
def bpr_recommendProducts(userID, top_howmany = 5):
    rec_items_bpr = np.inner(userMat[userID].T, prodMat)
    res_4_userID = []
    top_list = heapq.nlargest(top_howmany,rec_items_bpr)

    idx = 0
    for j in range(len(rec_items_bpr)):
        if rec_items_bpr[j] in top_list:
            res_4_userID.append((userID, j, top_list[idx])) 
            idx += 1
    return res_4_userID

# %% [markdown]
# ### voting

# %%
rec_items_cf = []
rec_items_bpr = []
for i in range(1, userMat.shape[0]):
    rec_items_cf.extend(CFmodel_.recommendProducts(i, top_howmany)) 
    rec_items_bpr.extend(bpr_recommendProducts(i, top_howmany))

# %% [markdown]
# * Result regularizing

# %%
cf_res_df = pd.DataFrame(rec_items_cf)
cf_devider = np.mean(cf_res_df.groupby('user').rating.max())
cf_res_df['rating'] = cf_res_df.rating/cf_devider

# %%
bpr_res_df = pd.DataFrame(rec_items_bpr)
bpr_res_df.columns = cf_res_df.columns
bpr_devider = np.mean(bpr_res_df.groupby('user').rating.max())
bpr_res_df['rating'] = bpr_res_df.rating/bpr_devider

# %% [markdown]
# * Generating overall results

# %%
overall_df = pd.concat([cf_res_df,bpr_res_df])
overall_df_show = overall_df.groupby(['user','product']).rating.sum()

# %% [markdown]
# * Selecting the most possible recommendations (from mid of the top values -- avoid overfitting)

# %%
def taking_out_reco_pairs(input_pairs, num = 5, init_pos = 8):
    _pairs_items = input_pairs.sort_values(ascending=False).index
    if len(_pairs_items)<init_pos+num:
        return _pairs_items[-num:]
    return _pairs_items[init_pos:init_pos+num]

# %%
overall_result = []
for i in range(1,userMat.shape[0]):
    overall_result.append([i, list(taking_out_reco_pairs(overall_df_show[i]))])

# %%
overall_result
# Out:
# [[1, [11890, 5565, 18508, 11387, 1226]],
#  [2, [1180, 24504, 5565, 108, 1226]],
#  [3, [18506, 5546, 10885, 108, 462]],
#  [4, [462, 20586, 11387, 10885, 1226]],
#  [5, [28081, 11387, 15280, 108, 1226]],
#  [6, [36429, 11052, 11102, 108, 1226]],
#  [7, [108, 16247, 15794, 11052, 462]],
#  [8, [108, 11387, 16247, 39780, 462]],
#  [9, [29844, 5546, 27675, 108, 1226]],
#  [10, [5154, 18508, 18506, 108, 1226]],
#  [11, [5547, 20053, 3909, 108, 462]],
#  [12, [28081, 25062, 18536, 108, 1226]],
#  [13, [5154, 11890, 4753, 15280, 1226]],
#  [14, [24504, 10885, 11890, 108, 1226]],
#  [15, [5154, 4753, 39780, 108, 1226]],
#  [16, [43427, 41707, 5562, 108, 1226]],
#  [17, [24504, 11890, 43427, 108, 462]],
#  [18, [92, 28074, 5565, 108, 1226]],
#  [19, [41238, 43427, 34457, 108, 1226]],
#  [20, [11387, 10884, 18508, 108, 462]],
#  [21, [1226, 10885, 8965, 15280, 4753]],
#  [22, [29844, 108, 11387, 11890, 462]],
#  [23, [11387, 15280, 5562, 43427, 6945]],
#  [24, [18508, 10885, 15794, 462, 1226]],
#  [25, [10885, 24504, 8965, 4753, 1226]],
#  [26, [11387, 5547, 20586, 18508, 462]],
#  [27, [20586, 11052, 8732, 108, 1226]],
#  [28, [29844, 5562, 11449, 108, 1226]],
#  [29, [11102, 15280, 18508, 108, 1226]],
#  [30, [39898, 10885, 20586, 462, 1226]],
#  [31, [4753, 44039, 20586, 108, 462]],
#  [32, [16247, 40780, 28241, 108, 462]],
#  [33, [11387, 11890, 11049, 108, 1226]],
#  [34, [26894, 18508, 43159, 108, 1226]],
#  [35, [108, 8965, 11890, 15280, 1226]],
#  [36, [38378, 39899, 10885, 108, 462]],
#  [37, [41000, 34457, 10884, 108, 462]],
#  [38, [10885, 18536, 10939, 108, 1226]],
#  [39, [10884, 16247, 19761, 108, 1226]],
#  [40, [36429, 41000, 10980, 108, 462]],
#  [41, [5546, 5545, 10939, 108, 1226]],
#  [42, [20586, 4753, 18508, 108, 462]],
#  [43, [16247, 43640, 43428, 108, 462]],
#  [44, [20586, 18536, 26894, 108, 1226]],
#  [45, [83, 8965, 1180, 108, 1226]],
#  [46, [18506, 4753, 5547, 108, 1226]],
#  [47, [18506, 16247, 39780, 108, 462]],
#  [48, [108, 11387, 10885, 20586, 1226]],
#  [49, [108, 18506, 18508, 11387, 1226]],
#  [50, [11890, 24504, 11387, 108, 1226]],
#  [51, [9010, 2658, 11102, 108, 1226]],
#  [52, [36429, 10980, 24504, 11387, 1226]],
#  [53, [24504, 11890, 18508, 108, 1226]],
#  [54, [18506, 25053, 28271, 108, 462]],
#  [55, [36829, 10885, 20053, 108, 1226]],
#  [56, [27362, 7398, 34284, 108, 1226]],
#  [57, [11890, 11387, 39780, 108, 1226]],
#  [58, [26894, 28081, 5154, 108, 1226]],
#  [59, [5565, 11387, 43427, 108, 1226]],
#  [60, [18506, 19761, 18508, 108, 1226]],
#  [61, [10853, 15280, 16247, 108, 1226]],
#  [62, [15280, 43427, 16247, 108, 1226]],
#  [63, [26894, 31415, 26896, 108, 462]],
#  [64, [4753, 44039, 5547, 108, 1226]],
#  [65, [39780, 39781, 36429, 462, 1226]],
#  [66, [15280, 20586, 10885, 108, 1226]],
#  [67, [10980, 10853, 36429, 5562, 1226]],
#  [68, [43427, 11387, 10884, 108, 462]],
#  [69, [11387, 10853, 8965, 10884, 1226]],
#  [70, [4753, 5565, 44039, 108, 462]],
#  [71, [18536, 5154, 33751, 108, 1226]],
#  [72, [10884, 108, 4753, 11387, 462]],
#  [73, [11102, 15280, 10980, 108, 1226]],
#  [74, [43159, 10884, 5545, 108, 462]],
#  [75, [15280, 108, 11890, 10885, 1226]],
#  [76, [15280, 36429, 108, 11101, 1226]],
#  [77, [18508, 10884, 24504, 1226, 11387]],
#  [78, [26896, 18506, 4753, 108, 1226]],
#  [79, [43427, 11387, 11890, 5154, 1226]],
#  [80, [18508, 5565, 29844, 108, 462]],
#  [81, [108, 26896, 15280, 39247, 1226]],
#  [82, [18508, 43159, 18506, 108, 1226]],
#  [83, [10853, 11890, 108, 11101, 462]],
#  [84, [20586, 10884, 26894, 108, 1226]],
#  [85, [5565, 39247, 44039, 3909, 462]],
#  [86, [4753, 10884, 43640, 108, 1226]],
#  [87, [33648, 29844, 5565, 108, 1226]],
#  [88, [43159, 28081, 18506, 108, 1226]],
#  [89, [11890, 36429, 43427, 8965, 1226]],
#  [90, [43159, 39780, 39781, 108, 1226]],
#  [91, [5154, 5565, 43640, 108, 1226]],
#  [92, [5565, 108, 11387, 11890, 1226]],
#  [93, [27362, 18536, 14, 108, 462]],
#  [94, [2560, 15280, 26894, 108, 462]],
#  [95, [39781, 15794, 29844, 108, 462]],
#  [96, [5565, 24504, 4753, 108, 462]],
#  [97, [10885, 30657, 12936, 462, 1226]],
#  [98, [108, 2658, 11890, 41000, 1226]],
#  [99, [10884, 16247, 15794, 108, 462]],
#  [100, [39780, 44039, 24504, 462, 1226]],
#  [101, [11049, 26987, 5547, 108, 462]],
#  [102, [41238, 43428, 18536, 108, 1226]],
#  [103, [11387, 5565, 1226, 10885, 24504]],
#  [104, [10884, 15280, 10885, 108, 462]],
#  [105, [15280, 18508, 25053, 108, 462]],
#  [106, [28242, 36429, 43159, 108, 1226]],
#  [107, [29044, 11890, 41000, 108, 1226]],
#  [108, [18506, 83, 34457, 462, 1226]],
#  [109, [8965, 11809, 10885, 108, 1226]],
#  [110, [11890, 41707, 27675, 108, 462]],
#  [111, [10885, 5356, 10853, 20586, 1226]],
#  [112, [11102, 5565, 4753, 108, 1226]],
#  [113, [19761, 15280, 36429, 108, 1226]],
#  [114, [3909, 19761, 11905, 108, 1226]],
#  [115, [10853, 15350, 5356, 108, 462]],
#  [116, [11101, 11387, 43427, 108, 1226]],
#  [117, [24504, 10885, 8965, 36429, 1226]],
#  [118, [10885, 11387, 24504, 5565, 1226]],
#  [119, [15350, 11730, 11101, 108, 1226]],
#  [120, [25403, 5547, 26896, 108, 1226]],
#  [121, [36829, 19761, 33751, 108, 462]],
#  [122, [11102, 29844, 11387, 462, 1226]],
#  [123, [39781, 36429, 33752, 108, 1226]],
#  [124, [10939, 108, 3909, 24504, 1226]],
#  [125, [11730, 9010, 33232, 1226, 6945]],
#  [126, [15280, 18508, 16247, 108, 1226]],
#  [127, [12900, 39898, 34284, 108, 462]],
#  [128, [10885, 4753, 19761, 108, 1226]],
#  [129, [11052, 43427, 43159, 108, 462]],
#  [130, [11890, 2658, 43427, 108, 1226]],
#  [131, [11387, 10853, 20586, 11102, 1226]],
#  [132, [4753, 11890, 8965, 9047, 1226]],
#  [133, [29844, 5356, 5476, 108, 1226]],
#  [134, [5154, 8965, 15280, 108, 462]],
#  [135, [16247, 36429, 41238, 108, 1226]],
#  [136, [5182, 8732, 83, 108, 1226]],
#  [137, [10885, 11387, 10853, 4753, 1226]],
#  [138, [5154, 26894, 28081, 108, 462]],
#  [139, [11102, 15794, 27675, 108, 1226]],
#  [140, [11387, 1226, 11890, 15280, 11052]],
#  [141, [10853, 8965, 16247, 1226, 6951]],
#  [142, [108, 24504, 11890, 36429, 1226]],
#  [143, [10939, 11387, 5547, 108, 1226]],
#  [144, [11387, 15280, 39898, 108, 1226]],
#  [145, [10884, 18506, 5547, 10885, 462]],
#  [146, [41238, 10884, 11101, 11890, 1226]],
#  [147, [20586, 43159, 26894, 108, 1226]],
#  [148, [2560, 11890, 27474, 108, 1226]],
#  [149, [28081, 40842, 33648, 108, 462]],
#  [150, [15794, 29844, 5547, 108, 1226]],
#  [151, [40661, 5547, 3909, 462, 1226]],
#  [152, [18508, 11102, 108, 24504, 1226]],
#  [153, [43427, 10885, 16994, 108, 462]],
#  [154, [16247, 5356, 5182, 108, 1226]],
#  [155, [15794, 2658, 11730, 108, 1226]],
#  [156, [15794, 10884, 39780, 108, 1226]],
#  [157, [11890, 10885, 33508, 108, 462]],
#  [158, [4753, 18536, 18508, 108, 1226]],
#  [159, [5565, 8732, 2658, 108, 1226]],
#  [160, [4753, 44039, 108, 20586, 1226]],
#  [161, [18536, 5565, 36429, 108, 462]],
#  [162, [10853, 11387, 15280, 26896, 1226]],
#  [163, [108, 16247, 11890, 15794, 462]],
#  [164, [11387, 11102, 8965, 108, 462]],
#  [165, [11890, 16247, 11387, 11102, 462]],
#  [166, [8965, 11102, 26896, 5154, 1226]],
#  [167, [32123, 108, 11890, 32108, 1226]],
#  [168, [20586, 10884, 11101, 108, 1226]],
#  [169, [11101, 5565, 15280, 108, 1226]],
#  [170, [18536, 15280, 15350, 108, 1226]],
#  [171, [36429, 39780, 39781, 1226, 6945]],
#  [172, [5547, 27362, 3909, 108, 1226]],
#  [173, [5154, 16247, 11890, 20586, 1226]],
#  [174, [31888, 43222, 29044, 108, 1226]],
#  [175, [10884, 41707, 15280, 108, 1226]],
#  [176, [26894, 11387, 10885, 108, 1226]],
#  [177, [10884, 11387, 15280, 11102, 1226]],
#  [178, [11890, 10885, 15280, 108, 1226]],
#  [179, [16247, 11052, 9827, 108, 1226]],
#  [180, [11387, 20586, 4753, 108, 462]],
#  [181, [8732, 11387, 28271, 108, 1226]],
#  [182, [10884, 5547, 24504, 108, 1226]],
#  [183, [4753, 18508, 18506, 108, 1226]],
#  [184, [11890, 11387, 10885, 108, 1226]],
#  [185, [20586, 43427, 11102, 10853, 1226]],
#  [186, [5546, 5545, 18508, 462, 1226]],
#  [187, [20586, 44039, 4753, 108, 462]],
#  [188, [8965, 11102, 24504, 5547, 1226]],
#  [189, [15280, 462, 43427, 11387, 1226]],
#  [190, [10884, 29044, 10853, 108, 462]],
#  [191, [11102, 5547, 5565, 108, 1226]],
#  [192, [18508, 10884, 43159, 108, 1226]],
#  [193, [10650, 43159, 24504, 108, 1226]],
#  [194, [20586, 18506, 10885, 462, 1226]],
#  [195, [10885, 11387, 24504, 462, 1226]],
#  [196, [5545, 11102, 43159, 108, 462]],
#  [197, [5565, 18508, 15794, 108, 1226]],
#  [198, [39898, 43427, 11387, 20586, 1226]],
#  [199, [8732, 5547, 3909, 10334, 1226]],
#  [200, [18508, 10885, 5546, 108, 1226]],
#  [201, [43159, 28081, 36829, 462, 1226]],
#  [202, [11101, 24504, 20586, 108, 1226]],
#  [203, [10980, 10853, 11102, 36429, 1226]],
#  [204, [108, 18508, 43427, 11102, 1226]],
#  [205, [10853, 10980, 11730, 108, 1226]],
#  [206, [5565, 4753, 11102, 108, 1226]],
#  [207, [10884, 18508, 39247, 108, 1226]],
#  [208, [29844, 20310, 33648, 108, 462]],
#  [209, [33648, 40842, 26894, 108, 1226]],
#  [210, [16247, 11890, 24504, 15280, 1226]],
#  [211, [43427, 15350, 108, 41238, 1226]],
#  [212, [5546, 83, 11449, 108, 1226]],
#  [213, [36429, 44039, 11890, 108, 1226]],
#  [214, [15794, 26896, 34457, 108, 462]],
#  [215, [11387, 5154, 36429, 108, 462]],
#  [216, [8965, 462, 10884, 10853, 9047]],
#  [217, [5154, 18536, 20586, 108, 1226]],
#  [218, [18536, 108, 5154, 26894, 462]],
#  [219, [18508, 39780, 39781, 108, 462]],
#  [220, [26894, 18508, 20586, 108, 1226]],
#  [221, [10885, 43427, 5547, 108, 1226]],
#  [222, [108, 4753, 44039, 11387, 1226]],
#  [223, [18536, 15794, 41000, 1226, 6945]],
#  [224, [462, 44039, 3909, 5546, 1226]],
#  [225, [10853, 41238, 5154, 108, 1226]],
#  [226, [36429, 18536, 11387, 108, 1226]],
#  [227, [11101, 2560, 20586, 108, 462]],
#  [228, [11387, 27362, 39780, 108, 1226]],
#  [229, [5154, 15280, 10885, 108, 1226]],
#  [230, [11890, 41000, 15794, 24504, 1226]],
#  [231, [36429, 20586, 11052, 108, 1226]],
#  [232, [20586, 15280, 18508, 108, 1226]],
#  [233, [108, 5154, 18506, 11048, 1226]],
#  [234, [24504, 26896, 8965, 462, 1226]],
#  [235, [39780, 39781, 24504, 29844, 1226]],
#  [236, [108, 15280, 11387, 18508, 1226]],
#  [237, [39898, 11387, 5154, 108, 1226]],
#  [238, [108, 11101, 11890, 11102, 1226]],
#  [239, [27362, 5547, 40661, 462, 1226]],
#  [240, [10980, 41238, 36429, 108, 462]],
#  [241, [15794, 30657, 9010, 108, 1226]],
#  [242, [5154, 5564, 11102, 108, 1226]],
#  [243, [24504, 10884, 43159, 108, 1226]],
#  [244, [18506, 41000, 34457, 108, 1226]],
#  [245, [5547, 11387, 41000, 108, 1226]],
#  [246, [28081, 35926, 28271, 108, 1226]],
#  [247, [39780, 39781, 8578, 108, 1226]],
#  [248, [41000, 10885, 108, 11890, 1226]],
#  [249, [18506, 5546, 10884, 108, 1226]],
#  [250, [10884, 39780, 39781, 462, 1226]],
#  [251, [11102, 1226, 10853, 11387, 20586]],
#  [252, [11890, 43427, 15280, 16247, 1226]],
#  [253, [10885, 5547, 44039, 108, 1226]],
#  [254, [10884, 10853, 34655, 108, 1226]],
#  [255, [10885, 29844, 6545, 108, 462]],
#  [256, [11101, 11102, 18536, 108, 1226]],
#  [257, [41707, 11890, 8578, 108, 1226]],
#  [258, [18506, 15794, 36429, 108, 462]],
#  [259, [4753, 38378, 26894, 108, 462]],
#  [260, [4753, 10884, 36429, 108, 1226]],
#  [261, [28081, 5547, 41000, 108, 1226]],
#  [262, [1180, 5476, 41238, 108, 1226]],
#  [263, [8965, 5565, 4753, 108, 462]],
#  [264, [4753, 5154, 10884, 1226, 6945]],
#  [265, [4753, 11890, 36429, 108, 1226]],
#  [266, [11102, 43427, 26896, 108, 1226]],
#  [267, [20586, 5154, 26896, 108, 1226]],
#  [268, [19761, 16247, 39781, 108, 462]],
#  [269, [4753, 18508, 18506, 108, 1226]],
#  [270, [10884, 18536, 83, 108, 1226]],
#  [271, [4753, 10884, 10885, 108, 1226]],
#  [272, [15350, 16247, 10884, 108, 1226]],
#  [273, [11101, 10884, 108, 11387, 1226]],
#  [274, [11387, 11730, 38010, 462, 1226]],
#  [275, [5565, 18506, 16247, 8965, 462]],
#  [276, [10885, 11101, 11890, 8965, 1226]],
#  [277, [10885, 8732, 8965, 108, 1226]],
#  [278, [19761, 20586, 31888, 1226, 6945]],
#  [279, [18506, 18508, 19761, 462, 1226]],
#  [280, [43159, 18506, 26894, 108, 462]],
#  [281, [11387, 11049, 26896, 5154, 1226]],
#  [282, [15280, 16247, 5547, 108, 1226]],
#  [283, [29844, 5546, 27675, 108, 1226]],
#  [284, [23413, 11102, 34457, 108, 462]],
#  [285, [36429, 12900, 34547, 108, 1226]],
#  [286, [5546, 5545, 27675, 108, 1226]],
#  [287, [5154, 5547, 10884, 108, 462]],
#  [288, [5565, 11387, 10885, 108, 1226]],
#  [289, [5546, 8732, 11890, 108, 1226]],
#  [290, [26896, 10650, 5545, 108, 462]],
#  [291, [4753, 20586, 108, 44039, 462]],
#  [292, [24504, 11890, 36429, 18508, 1226]],
#  [293, [108, 5565, 20586, 28081, 1226]],
#  [294, [36429, 41000, 11052, 108, 1226]],
#  [295, [5154, 18506, 26896, 108, 1226]],
#  [296, [18508, 39247, 33648, 108, 462]],
#  [297, [1180, 11101, 27474, 108, 462]],
#  [298, [10853, 10980, 11058, 108, 462]],
#  [299, [10980, 11387, 31865, 108, 462]],
#  [300, [4753, 108, 10853, 11890, 1226]],
#  [301, [5565, 27675, 36429, 108, 1226]],
#  [302, [39781, 29844, 24504, 462, 1226]],
#  [303, [11890, 35926, 36429, 108, 1226]],
#  [304, [10884, 10853, 1180, 108, 1226]],
#  [305, [15280, 11058, 5562, 108, 1226]],
#  [306, [108, 18506, 11387, 10884, 1226]],
#  [307, [10853, 11387, 11102, 108, 1226]],
#  [308, [15280, 11387, 108, 4753, 1226]],
#  [309, [39780, 5154, 108, 16247, 1226]],
#  [310, [24504, 11387, 10853, 18508, 1226]],
#  [311, [22890, 24504, 19841, 108, 1226]],
#  [312, [5154, 5547, 10884, 108, 1226]],
#  [313, [4753, 11387, 5154, 108, 462]],
#  [314, [36429, 11890, 11387, 108, 1226]],
#  [315, [39781, 39780, 16247, 108, 1226]],
#  [316, [11387, 108, 10853, 38378, 1226]],
#  [317, [108, 10885, 11387, 8965, 1226]],
#  [318, [18508, 15280, 5154, 10650, 1226]],
#  [319, [36429, 11387, 11890, 108, 1226]],
#  [320, [5565, 18506, 4753, 108, 462]],
#  [321, [5547, 11102, 1180, 108, 1226]],
#  [322, [11101, 11890, 18508, 108, 1226]],
#  [323, [27362, 11102, 8965, 108, 462]],
#  [324, [5565, 44039, 20586, 462, 1226]],
#  [325, [11102, 34457, 18506, 108, 1226]],
#  [326, [35926, 18536, 39247, 108, 1226]],
#  [327, [11387, 5565, 108, 26896, 1226]],
#  [328, [39780, 39781, 5565, 108, 1226]],
#  [329, [38378, 26894, 37762, 108, 1226]],
#  [330, [18508, 15280, 11890, 108, 1226]],
#  [331, [4753, 5562, 10853, 108, 1226]],
#  [332, [8965, 5154, 5547, 15280, 1226]],
#  [333, [26896, 9827, 40780, 108, 462]],
#  [334, [5565, 11890, 5546, 1226, 6945]],
#  [335, [18506, 16247, 10939, 108, 462]],
#  [336, [11102, 11387, 108, 8965, 1226]],
#  [337, [18506, 18508, 34457, 108, 462]],
#  [338, [11890, 43222, 2658, 108, 1226]],
#  [339, [10884, 43427, 11102, 108, 1226]],
#  [340, [19841, 11102, 5154, 8965, 1226]],
#  [341, [5154, 108, 20586, 11387, 1226]],
#  [342, [11387, 18536, 28202, 108, 462]],
#  [343, [34547, 15280, 31888, 108, 462]],
#  [344, [43159, 18508, 18506, 108, 1226]],
#  [345, [11387, 43427, 108, 11890, 1226]],
#  [346, [11101, 36429, 26896, 108, 1226]],
#  [347, [29844, 5562, 19841, 108, 462]],
#  [348, [18508, 10884, 39247, 108, 1226]],
#  [349, [24504, 10939, 4753, 108, 462]],
#  [350, [5356, 10885, 10884, 108, 1226]],
#  [351, [29044, 5565, 10980, 108, 1226]],
#  [352, [10853, 16247, 15280, 108, 1226]],
#  [353, [11101, 12936, 11052, 108, 462]],
#  [354, [5547, 5154, 108, 11387, 462]],
#  [355, [1922, 20586, 11049, 108, 1226]],
#  [356, [10884, 26896, 10885, 108, 1226]],
#  [357, [10884, 11102, 108, 10853, 462]],
#  [358, [11049, 15280, 4753, 108, 462]],
#  [359, [5154, 39781, 39780, 108, 462]],
#  [360, [36429, 10853, 5546, 1180, 1226]],
#  [361, [18536, 5565, 4753, 108, 462]],
#  [362, [18508, 18506, 43427, 15794, 1226]],
#  [363, [24504, 10853, 15280, 8965, 1226]],
#  [364, [15280, 108, 18508, 11890, 462]],
#  [365, [10885, 43427, 4753, 44039, 462]],
#  [366, [5154, 8965, 11387, 26896, 1226]],
#  [367, [18506, 11387, 1922, 108, 1226]],
#  [368, [11101, 26896, 10853, 10980, 1226]],
#  [369, [18536, 34284, 92, 108, 462]],
#  [370, [26894, 26896, 44039, 108, 1226]],
#  [371, [10980, 11890, 16247, 108, 1226]],
#  [372, [11102, 24504, 10885, 108, 462]],
#  [373, [5154, 43640, 28241, 108, 1226]],
#  [374, [11102, 18508, 108, 33648, 1226]],
#  [375, [5154, 1226, 8965, 4753, 16247]],
#  [376, [11102, 10853, 29844, 24504, 1226]],
#  [377, [39899, 11048, 5154, 108, 462]],
#  [378, [108, 11052, 11890, 8732, 462]],
#  [379, [4753, 11387, 108, 8965, 1226]],
#  [380, [18536, 12900, 5564, 108, 462]],
#  [381, [18536, 26896, 8965, 108, 462]],
#  [382, [26896, 18506, 20310, 108, 462]],
#  [383, [15280, 5356, 11052, 108, 1226]],
#  [384, [11890, 11387, 39247, 24504, 1226]],
#  [385, [5547, 39780, 39781, 108, 1226]],
#  [386, [16247, 36829, 15794, 5547, 1226]],
#  [387, [2560, 26894, 19761, 108, 1226]],
#  [388, [18535, 5356, 16247, 108, 1226]],
#  [389, [18506, 26896, 3909, 108, 462]],
#  [390, [2560, 15161, 40842, 108, 462]],
#  [391, [15794, 15280, 16247, 108, 1226]],
#  [392, [10884, 11387, 8965, 4753, 1226]],
#  [393, [5547, 43427, 5182, 108, 1226]],
#  [394, [5546, 43159, 36429, 108, 1226]],
#  [395, [11387, 5154, 10884, 108, 1226]],
#  [396, [44039, 4753, 24766, 108, 1226]],
#  [397, [5565, 16247, 15794, 108, 1226]],
#  [398, [27362, 14, 29844, 108, 462]],
#  [399, [41000, 5547, 15794, 108, 1226]],
#  [400, [2560, 12936, 15280, 108, 1226]],
#  [401, [24504, 11387, 20586, 108, 1226]],
#  [402, [36429, 41000, 20586, 108, 462]],
#  [403, [41000, 4753, 39781, 108, 1226]],
#  [404, [15280, 10884, 10853, 108, 1226]],
#  [405, [5565, 44039, 20586, 462, 1226]],
#  [406, [11052, 1180, 10853, 108, 1226]],
#  [407, [28839, 34284, 15161, 108, 1226]],
#  [408, [8965, 108, 10884, 41238, 1226]],
#  [409, [20586, 11102, 15794, 108, 1226]],
#  [410, [15280, 10884, 11387, 108, 1226]],
#  [411, [36429, 11387, 11101, 10853, 462]],
#  [412, [11387, 39247, 24504, 108, 1226]],
#  [413, [108, 16247, 20053, 5562, 1226]],
#  [414, [39780, 39781, 44039, 108, 1226]],
#  [415, [39247, 5154, 10650, 108, 1226]],
#  [416, [26896, 11102, 43427, 11387, 1226]],
#  [417, [10885, 11387, 28081, 108, 1226]],
#  [418, [27362, 5545, 12900, 108, 1226]],
#  [419, [20586, 36829, 10650, 108, 1226]],
#  [420, [5545, 2560, 92, 108, 1226]],
#  [421, [18508, 11102, 16247, 108, 1226]],
#  [422, [20053, 5476, 27362, 108, 462]],
#  [423, [24504, 10885, 5547, 108, 1226]],
#  [424, [11890, 15280, 28839, 108, 1226]],
#  [425, [11102, 22890, 33648, 108, 1226]],
#  [426, [10885, 39781, 39780, 108, 462]],
#  [427, [11890, 11052, 31277, 108, 1226]],
#  [428, [39780, 108, 11102, 16247, 1226]],
#  [429, [5565, 19761, 28081, 462, 1226]],
#  [430, [11890, 10980, 41238, 108, 462]],
#  [431, [16247, 5562, 19841, 108, 1226]],
#  [432, [2658, 41000, 43222, 108, 1226]],
#  [433, [24504, 18506, 18508, 108, 1226]],
#  [434, [9827, 11890, 8578, 108, 1226]],
#  [435, [11387, 11890, 10884, 8965, 6945]],
#  [436, [5154, 18508, 11049, 462, 1226]],
#  [437, [10885, 24504, 10884, 8965, 1226]],
#  [438, [108, 36429, 11101, 11890, 1226]],
#  [439, [10884, 43159, 11102, 108, 1226]],
#  [440, [108, 41238, 11387, 15280, 1226]],
#  [441, [18536, 20586, 5565, 4753, 1226]],
#  [442, [11387, 10853, 11730, 108, 1226]],
#  [443, [15280, 18536, 11101, 108, 462]],
#  [444, [11101, 26896, 16247, 108, 1226]],
#  [445, [10980, 5356, 83, 108, 1226]],
#  [446, [11387, 3909, 16247, 108, 1226]],
#  [447, [43159, 5547, 39780, 108, 1226]],
#  [448, [5546, 11102, 15794, 108, 462]],
#  [449, [1226, 24504, 36429, 39780, 39781]],
#  [450, [39780, 29844, 27675, 108, 1226]],
#  [451, [24504, 5565, 11052, 462, 1226]],
#  [452, [11102, 5565, 3909, 108, 1226]],
#  [453, [10884, 18508, 108, 44039, 1226]],
#  [454, [15280, 108, 11387, 18536, 1226]],
#  [455, [11387, 11890, 36429, 3909, 1226]],
#  [456, [11049, 3909, 18508, 108, 1226]],
#  [457, [4753, 26896, 5154, 108, 1226]],
#  [458, [29844, 5546, 11102, 108, 1226]],
#  [459, [29844, 26896, 30657, 108, 1226]],
#  [460, [11049, 5564, 10885, 108, 1226]],
#  [461, [11102, 29044, 6945, 6951, 41462]],
#  [462, [44039, 5547, 4753, 108, 1226]],
#  [463, [43427, 10853, 29044, 108, 1226]],
#  [464, [41000, 2658, 3909, 462, 1226]],
#  [465, [15280, 108, 5562, 26896, 1226]],
#  [466, [18536, 36429, 20586, 108, 1226]],
#  [467, [19761, 20586, 11052, 108, 462]],
#  [468, [5356, 24504, 5151, 108, 1226]],
#  [469, [33232, 5564, 10885, 108, 1226]],
#  [470, [8578, 20586, 5565, 108, 1226]],
#  [471, [11387, 12304, 39247, 108, 462]],
#  [472, [5546, 11102, 12900, 462, 1226]],
#  [473, [108, 39781, 39780, 36429, 1226]],
#  [474, [10853, 11387, 24504, 11890, 1226]],
#  [475, [15280, 10885, 11101, 108, 462]],
#  [476, [3909, 8732, 44039, 108, 462]],
#  [477, [4753, 18508, 36829, 108, 1226]],
#  [478, [11387, 108, 24504, 8965, 1226]],
#  [479, [10885, 11102, 12900, 108, 1226]],
#  [480, [8732, 8965, 40661, 108, 1226]],
#  [481, [18506, 10885, 36829, 108, 462]],
#  [482, [5154, 39780, 39781, 108, 462]],
#  [483, [27675, 15280, 28839, 108, 1226]],
#  [484, [16247, 10884, 5565, 108, 1226]],
#  [485, [24504, 11387, 20586, 10884, 1226]],
#  [486, [108, 11102, 10885, 15280, 462]],
#  [487, [2165, 18508, 28202, 108, 462]],
#  [488, [4753, 15280, 5562, 108, 1226]],
#  [489, [108, 10885, 20586, 11387, 1226]],
#  [490, [4753, 10885, 108, 44039, 1226]],
#  [491, [10885, 11890, 36429, 20586, 1226]],
#  [492, [10853, 29844, 8965, 11890, 462]],
#  [493, [15280, 43159, 18506, 108, 462]],
#  [494, [28081, 11387, 36429, 108, 1226]],
#  [495, [44039, 3909, 35926, 108, 1226]],
#  [496, [5154, 4753, 18508, 462, 1226]],
#  [497, [41000, 10884, 18508, 108, 1226]],
#  [498, [26894, 4753, 36429, 108, 462]],
#  [499, [29844, 30657, 18536, 462, 1226]],
#  [500, [33648, 29844, 43427, 108, 1226]],
#  [501, [83, 5547, 11102, 108, 1226]],
#  [502, [16752, 36429, 22067, 108, 1226]],
#  [503, [11890, 16247, 18508, 108, 1226]],
#  [504, [18506, 11387, 24504, 11102, 1226]],
#  [505, [20586, 5154, 108, 11387, 462]],
#  [506, [18506, 41000, 5676, 108, 1226]],
#  [507, [43427, 41000, 18536, 108, 1226]],
#  [508, [29844, 5476, 5356, 108, 1226]],
#  [509, [5545, 36429, 43159, 108, 462]],
#  [510, [39781, 39780, 5565, 108, 1226]],
#  [511, [108, 10884, 26896, 4753, 462]],
#  [512, [44039, 4753, 39780, 108, 462]],
#  [513, [83, 1180, 10853, 108, 1226]],
#  [514, [18536, 11890, 8965, 11101, 1226]],
#  [515, [27053, 18517, 42021, 108, 1226]],
#  [516, [11387, 5547, 20586, 108, 1226]],
#  [517, [24504, 11387, 5547, 39780, 1226]],
#  [518, [4753, 39898, 5154, 108, 1226]],
#  [519, [11890, 2658, 43222, 108, 462]],
#  [520, [108, 15280, 8965, 8732, 462]],
#  [521, [35926, 11052, 10885, 108, 1226]],
#  [522, [1180, 5562, 24504, 108, 462]],
#  [523, [26894, 19761, 15280, 108, 1226]],
#  [524, [4753, 18508, 18506, 108, 1226]],
#  [525, [43427, 108, 44039, 11052, 1226]],
#  [526, [18536, 108, 40661, 10800, 1226]],
#  [527, [4753, 44039, 20586, 108, 462]],
#  [528, [18508, 18506, 5547, 108, 1226]],
#  [529, [18506, 19761, 18508, 108, 462]],
#  [530, [39247, 18508, 4753, 108, 1226]],
#  [531, [108, 11387, 11102, 8965, 462]],
#  [532, [11052, 10980, 5562, 108, 1226]],
#  [533, [26896, 8965, 43427, 11387, 1226]],
#  [534, [10884, 33648, 18506, 1226, 6945]],
#  [535, [16477, 15280, 41238, 108, 462]],
#  [536, [4753, 26894, 10884, 108, 462]],
#  [537, [5545, 5546, 43159, 108, 1226]],
#  [538, [4753, 43427, 26896, 108, 462]],
#  [539, [5154, 5547, 18508, 108, 1226]],
#  [540, [11890, 36429, 10885, 108, 1226]],
#  [541, [5154, 10853, 11387, 28081, 1226]],
#  [542, [19761, 26894, 18508, 108, 462]],
#  [543, [1226, 5154, 11101, 6945, 6951]],
#  [544, [11387, 1226, 4753, 8965, 10853]],
#  [545, [11387, 11890, 28081, 108, 1226]],
#  [546, [15280, 11052, 10853, 108, 1226]],
#  [547, [10884, 8578, 11101, 108, 462]],
#  [548, [10884, 4753, 11049, 108, 1226]],
#  [549, [26896, 108, 43427, 11387, 1226]],
#  [550, [10885, 108, 11890, 15280, 462]],
#  [551, [43159, 28241, 39898, 108, 1226]],
#  [552, [83, 27675, 8965, 39781, 1226]],
#  [553, [20586, 11101, 24504, 5356, 1226]],
#  [554, [11101, 5565, 9010, 108, 1226]],
#  [555, [8965, 10853, 4753, 108, 1226]],
#  [556, [11387, 108, 15280, 10884, 1226]],
#  [557, [11890, 43427, 10853, 15280, 1226]],
#  [558, [10884, 8732, 5565, 108, 1226]],
#  [559, [27362, 3909, 92, 108, 1226]],
#  [560, [11102, 5545, 5154, 108, 462]],
#  [561, [41707, 39898, 92, 108, 462]],
#  [562, [24504, 8965, 15280, 10884, 1226]],
#  [563, [11890, 5565, 36429, 11387, 462]],
#  [564, [11102, 10853, 41000, 108, 1226]],
#  [565, [28241, 40780, 30657, 462, 1226]],
#  [566, [34284, 22890, 5565, 108, 1226]],
#  [567, [5565, 11387, 8965, 4753, 1226]],
#  [568, [10884, 33751, 10885, 108, 1226]],
#  [569, [24504, 11387, 18506, 108, 462]],
#  [570, [11102, 24504, 1226, 5154, 6945]],
#  [571, [36429, 18508, 11102, 108, 462]],
#  [572, [10853, 11890, 15280, 11387, 462]],
#  [573, [11102, 108, 11387, 26896, 1226]],
#  [574, [5565, 4753, 19761, 108, 1226]],
#  [575, [11058, 31888, 5562, 108, 1226]],
#  [576, [20586, 36429, 35926, 108, 1226]],
#  [577, [28081, 18506, 11387, 108, 462]],
#  [578, [15280, 10884, 18506, 108, 1226]],
#  [579, [41000, 15794, 43159, 462, 1226]],
#  [580, [43427, 16247, 36429, 5562, 5516]],
#  [581, [43427, 36429, 11387, 11890, 462]],
#  [582, [24504, 10885, 5356, 5546, 1226]],
#  [583, [108, 10884, 11049, 11890, 1226]],
#  [584, [10853, 11102, 2560, 108, 1226]],
#  [585, [26896, 29844, 20053, 108, 1226]],
#  [586, [43427, 4753, 11049, 26896, 462]],
#  [587, [19761, 10884, 20586, 108, 1226]],
#  [588, [11052, 18508, 20586, 108, 1226]],
#  [589, [18536, 26896, 10884, 9827, 1226]],
#  [590, [11102, 462, 8965, 16247, 10884]],
#  [591, [10885, 11387, 108, 12936, 1226]],
#  [592, [18536, 11387, 15280, 20586, 462]],
#  [593, [41707, 43159, 15280, 108, 1226]],
#  [594, [8732, 108, 3909, 9010, 1226]],
#  [595, [36829, 11049, 10885, 108, 1226]],
#  [596, [11387, 41238, 16247, 18506, 1226]],
#  [597, [10885, 11387, 26896, 108, 1226]],
#  [598, [10885, 5565, 11890, 8965, 1226]],
#  [599, [20053, 22890, 34284, 108, 462]],
#  [600, [5154, 108, 26894, 11387, 1226]],
#  [601, [5562, 1180, 108, 10853, 1226]],
#  [602, [5154, 27362, 5547, 108, 462]],
#  [603, [10800, 44039, 26894, 108, 1226]],
#  [604, [18536, 11387, 5154, 108, 1226]],
#  [605, [29844, 11102, 16247, 43427, 1226]],
#  [606, [30657, 5547, 18506, 108, 462]],
#  [607, [5562, 10853, 11387, 108, 462]],
#  [608, [15280, 18508, 11102, 108, 1226]],
#  [609, [18536, 11890, 5565, 11387, 1226]],
#  [610, [15280, 10884, 19761, 108, 462]],
#  [611, [11387, 11890, 36429, 16247, 1226]],
#  [612, [24504, 11387, 10885, 1226, 8965]],
#  [613, [36429, 10980, 5562, 108, 1226]],
#  [614, [11387, 22067, 26896, 108, 1226]],
#  [615, [11387, 11730, 18536, 11049, 1226]],
#  [616, [18536, 44039, 10885, 108, 1226]],
#  [617, [11387, 41238, 11102, 1180, 1226]],
#  [618, [24504, 18508, 28081, 108, 1226]],
#  [619, [11102, 5154, 18508, 108, 462]],
#  [620, [10980, 1180, 24504, 462, 1226]],
#  [621, [5547, 41238, 16247, 108, 462]],
#  [622, [11102, 5547, 26896, 108, 1226]],
#  [623, [43427, 11890, 8965, 36429, 1226]],
#  [624, [43427, 2560, 18506, 108, 462]],
#  [625, [5565, 41000, 9010, 1226, 6945]],
#  [626, [16247, 11102, 11890, 108, 1226]],
#  [627, [108, 15280, 18508, 10650, 1226]],
#  [628, [43427, 108, 11890, 4753, 1226]],
#  [629, [5356, 11890, 11101, 10885, 1226]],
#  [630, [5565, 18506, 11102, 108, 1226]],
#  [631, [41238, 4753, 5154, 108, 1226]],
#  [632, [10885, 11387, 39781, 39780, 1226]],
#  [633, [36429, 29844, 11890, 108, 1226]],
#  [634, [11102, 43427, 10885, 108, 1226]],
#  [635, [15280, 11387, 8965, 108, 1226]],
#  [636, [11101, 33232, 34457, 108, 1226]],
#  [637, [10885, 5546, 108, 10884, 1226]],
#  [638, [4753, 16247, 11890, 5565, 1226]],
#  [639, [11387, 24504, 11730, 108, 462]],
#  [640, [11387, 4753, 29844, 5154, 1226]],
#  [641, [44039, 39781, 39780, 108, 1226]],
#  [642, [20586, 24504, 11890, 11387, 462]],
#  [643, [22890, 28081, 18508, 108, 1226]],
#  [644, [4753, 2560, 11387, 108, 1226]],
#  [645, [4753, 11387, 15280, 108, 1226]],
#  [646, [18506, 5547, 44039, 108, 1226]],
#  [647, [11387, 10800, 20586, 108, 462]],
#  [648, [11890, 108, 11387, 15350, 1226]],
#  [649, [20586, 19761, 10884, 108, 1226]],
#  [650, [18508, 10334, 18506, 108, 462]],
#  [651, [11387, 1226, 39781, 39780, 10885]],
#  [652, [10885, 11387, 10800, 108, 462]],
#  [653, [11387, 43427, 10885, 8965, 462]],
#  [654, [36429, 11890, 11387, 15280, 1226]],
#  [655, [24504, 11890, 11387, 108, 462]],
#  [656, [11387, 15280, 36429, 5356, 1226]],
#  [657, [11052, 15280, 18508, 108, 462]],
#  [658, [108, 29044, 11052, 11102, 1226]],
#  [659, [11387, 4753, 15280, 108, 462]],
#  [660, [5547, 3909, 20586, 108, 1226]],
#  [661, [20586, 29844, 5565, 11387, 1226]],
#  [662, [26896, 11101, 5154, 108, 1226]],
#  [663, [11102, 2560, 15280, 108, 1226]],
#  [664, [41000, 16247, 31888, 108, 1226]],
#  [665, [24504, 16247, 15280, 462, 1226]],
#  [666, [3909, 19761, 10884, 108, 1226]],
#  [667, [24504, 43427, 1226, 8965, 5547]],
#  [668, [5545, 15794, 92, 108, 1226]],
#  [669, [108, 10884, 11387, 43159, 1226]],
#  [670, [108, 26896, 8965, 16247, 462]],
#  [671, [4753, 11387, 41238, 5154, 462]],
#  [672, [39899, 11052, 9827, 108, 1226]],
#  [673, [10885, 44039, 10884, 108, 1226]],
#  [674, [92, 9827, 27474, 108, 1226]],
#  [675, [41707, 36429, 15280, 108, 1226]],
#  [676, [10853, 11449, 35926, 108, 1226]],
#  [677, [24504, 11387, 108, 39780, 1226]],
#  [678, [83, 36429, 43427, 108, 1226]],
#  [679, [18508, 41000, 29044, 1226, 6945]],
#  [680, [11890, 15280, 5564, 108, 1226]],
#  [681, [33648, 5565, 41238, 108, 1226]],
#  [682, [3909, 43427, 18536, 108, 462]],
#  [683, [43427, 16247, 10980, 108, 1226]],
#  [684, [18508, 32108, 11387, 108, 1226]],
#  [685, [18508, 10884, 11049, 108, 462]],
#  [686, [11102, 2165, 29044, 1226, 6945]],
#  [687, [5154, 5547, 18506, 108, 1226]],
#  [688, [15280, 11890, 36429, 108, 1226]],
#  [689, [18506, 3909, 10334, 108, 1226]],
#  [690, [20053, 11052, 38378, 108, 1226]],
#  [691, [43159, 5154, 18508, 108, 462]],
#  [692, [10781, 3909, 30657, 108, 1226]],
#  [693, [25403, 44039, 26894, 108, 1226]],
#  [694, [10800, 3909, 30657, 108, 1226]],
#  [695, [5562, 5151, 36829, 108, 1226]],
#  [696, [2560, 10650, 34284, 108, 1226]],
#  [697, [10939, 5547, 11387, 108, 1226]],
#  [698, [19761, 11387, 10885, 108, 1226]],
#  [699, [18536, 3909, 11387, 108, 1226]],
#  [700, [10884, 24504, 29844, 108, 1226]],
#  [701, [39780, 39781, 3909, 462, 1226]],
#  [702, [20586, 11387, 28081, 108, 1226]],
#  [703, [11102, 5545, 18508, 108, 1226]],
#  [704, [108, 11890, 11101, 9827, 1226]],
#  [705, [15350, 29044, 10853, 108, 462]],
#  [706, [10884, 5154, 11101, 11387, 1226]],
#  [707, [5154, 26896, 5565, 108, 1226]],
#  [708, [5547, 18508, 11387, 108, 1226]],
#  [709, [10884, 27362, 11049, 108, 1226]],
#  [710, [83, 6545, 31415, 108, 1226]],
#  [711, [18536, 8732, 11052, 462, 1226]],
#  [712, [5565, 5546, 8965, 108, 1226]],
#  [713, [20586, 22890, 5562, 108, 1226]],
#  [714, [18506, 41238, 5476, 108, 1226]],
#  [715, [18536, 15350, 10853, 108, 462]],
#  [716, [20586, 10885, 29844, 108, 1226]],
#  [717, [18517, 18507, 28202, 462, 1226]],
#  [718, [10884, 19761, 18508, 108, 1226]],
#  [719, [5545, 36429, 44039, 108, 1226]],
#  [720, [5565, 11387, 39898, 462, 1226]],
#  [721, [5547, 5154, 43428, 108, 1226]],
#  [722, [10884, 11387, 11102, 108, 1226]],
#  [723, [11102, 36429, 11890, 108, 1226]],
#  [724, [11101, 15280, 10853, 462, 1226]],
#  [725, [43427, 28081, 11052, 108, 1226]],
#  [726, [108, 18506, 43427, 11890, 1226]],
#  [727, [36429, 8578, 5154, 108, 462]],
#  [728, [5516, 35650, 29844, 108, 1226]],
#  [729, [5547, 11387, 30657, 108, 462]],
#  [730, [16247, 36429, 31277, 108, 1226]],
#  [731, [108, 10884, 18536, 11730, 1226]],
#  [732, [10939, 39781, 39780, 108, 1226]],
#  [733, [5565, 29844, 19761, 462, 1226]],
#  [734, [11890, 15794, 11102, 108, 462]],
#  [735, [20586, 20053, 1180, 108, 1226]],
#  [736, [11387, 10853, 41238, 108, 1226]],
#  [737, [36429, 11052, 11890, 108, 1226]],
#  [738, [11890, 36429, 20586, 108, 1226]],
#  [739, [5547, 10939, 15794, 1226, 6945]],
#  [740, [18536, 26896, 11387, 108, 1226]],
#  [741, [15280, 3909, 20586, 108, 1226]],
#  [742, [36829, 18536, 10885, 108, 1226]],
#  [743, [11052, 28081, 11049, 1226, 6951]],
#  [744, [5565, 20586, 11387, 108, 1226]],
#  [745, [4753, 16247, 11102, 108, 462]],
#  [746, [11387, 43427, 36429, 10853, 1226]],
#  [747, [11387, 5154, 26894, 108, 1226]],
#  [748, [108, 18508, 11102, 11387, 1226]],
#  [749, [11387, 24504, 39899, 108, 462]],
#  [750, [10884, 15280, 108, 11387, 1226]],
#  [751, [11890, 16247, 36429, 10885, 1226]],
#  [752, [16247, 11387, 15794, 108, 1226]],
#  [753, [39247, 5154, 5546, 108, 1226]],
#  [754, [15280, 20586, 11890, 1226, 6945]],
#  [755, [26896, 11102, 10884, 108, 1226]],
#  [756, [18508, 4753, 39898, 108, 462]],
#  [757, [43159, 11102, 36829, 108, 1226]],
#  [758, [33751, 43427, 34835, 108, 462]],
#  [759, [11387, 4753, 43427, 108, 462]],
#  [760, [108, 10885, 11101, 11387, 1226]],
#  [761, [43427, 8965, 11102, 5562, 1226]],
#  [762, [43159, 15280, 15161, 462, 1226]],
#  [763, [5565, 41238, 4753, 108, 1226]],
#  [764, [39781, 11102, 43159, 108, 462]],
#  [765, [5546, 92, 29234, 108, 1226]],
#  [766, [18536, 6545, 1180, 108, 1226]],
#  [767, [41238, 5565, 18507, 108, 1226]],
#  [768, [11101, 1180, 108, 41238, 462]],
#  [769, [19761, 18508, 43427, 108, 1226]],
#  [770, [11890, 11058, 11102, 108, 462]],
#  [771, [18506, 10885, 24504, 108, 1226]],
#  [772, [5565, 33648, 34284, 108, 1226]],
#  [773, [39781, 39780, 11387, 108, 462]],
#  [774, [11102, 18508, 43427, 108, 1226]],
#  [775, [20586, 11890, 10853, 108, 1226]],
#  [776, [19761, 18536, 10939, 108, 462]],
#  [777, [39247, 3909, 20586, 108, 1226]],
#  [778, [16247, 5356, 5562, 108, 1226]],
#  [779, [15350, 2658, 10885, 108, 1226]],
#  [780, [39247, 11387, 43428, 108, 462]],
#  [781, [83, 34284, 92, 108, 1226]],
#  [782, [24504, 8965, 10884, 11102, 1226]],
#  [783, [31888, 10853, 11102, 108, 462]],
#  [784, [41238, 10980, 15161, 108, 1226]],
#  [785, [27474, 11102, 10853, 108, 1226]],
#  [786, [4753, 11387, 26896, 8965, 462]],
#  [787, [108, 43427, 30657, 1922, 1226]],
#  [788, [39781, 39780, 16247, 108, 1226]],
#  [789, [11387, 11890, 24504, 36429, 462]],
#  [790, [41238, 10853, 26896, 108, 1226]],
#  [791, [11102, 36429, 5154, 108, 462]],
#  [792, [11049, 15280, 8732, 20586, 1226]],
#  [793, [19761, 43159, 36829, 108, 462]],
#  [794, [5154, 18506, 11387, 108, 1226]],
#  [795, [26896, 5154, 462, 41238, 1226]],
#  [796, [5565, 3909, 10334, 108, 1226]],
#  [797, [18508, 16247, 5676, 462, 1226]],
#  [798, [11890, 9827, 18536, 108, 462]],
#  [799, [18508, 5154, 1180, 108, 1226]],
#  [800, [10885, 18536, 9047, 108, 462]],
#  [801, [11890, 16247, 36429, 24504, 4753]],
#  [802, [15794, 24504, 5356, 108, 1226]],
#  [803, [41238, 11102, 10853, 108, 462]],
#  [804, [11102, 83, 8965, 11387, 1226]],
#  [805, [10885, 44039, 10334, 108, 1226]],
#  [806, [36829, 20053, 33232, 108, 1226]],
#  [807, [16247, 5154, 20310, 108, 1226]],
#  [808, [5565, 26896, 108, 8965, 1226]],
#  [809, [43427, 462, 18506, 11387, 1226]],
#  [810, [3909, 43159, 5356, 108, 1226]],
#  [811, [11387, 18506, 18508, 29844, 462]],
#  [812, [5547, 83, 4753, 108, 462]],
#  [813, [15794, 18506, 19761, 108, 1226]],
#  [814, [4753, 11387, 11890, 462, 1226]],
#  [815, [11102, 11101, 10885, 108, 462]],
#  [816, [5547, 18508, 30864, 108, 1226]],
#  [817, [11102, 16247, 11387, 108, 462]],
#  [818, [10885, 11102, 15280, 8965, 1226]],
#  [819, [5565, 10885, 5154, 108, 1226]],
#  [820, [43427, 11102, 11387, 11058, 1226]],
#  [821, [26894, 18536, 18507, 108, 1226]],
#  [822, [11387, 5547, 8965, 108, 462]],
#  [823, [36429, 27362, 40780, 108, 1226]],
#  [824, [10885, 108, 26896, 10650, 1226]],
#  [825, [11890, 43159, 108, 28839, 1226]],
#  [826, [11101, 11890, 10885, 108, 462]],
#  [827, [5565, 108, 3909, 18506, 1226]],
#  [828, [9827, 4753, 20586, 108, 462]],
#  [829, [36429, 16247, 9827, 15794, 462]],
#  [830, [28081, 44039, 890, 108, 462]],
#  [831, [18508, 29844, 11387, 19841, 1226]],
#  [832, [5154, 11387, 24504, 108, 1226]],
#  [833, [20586, 24504, 18508, 44039, 1226]],
#  [834, [10884, 10853, 18508, 1180, 462]],
#  [835, [43427, 43159, 10650, 108, 1226]],
#  [836, [10884, 43159, 15794, 108, 1226]],
#  [837, [11890, 15161, 36429, 108, 1226]],
#  [838, [31415, 33751, 10885, 108, 1226]],
#  [839, [39781, 11102, 43159, 108, 1226]],
#  [840, [26896, 11049, 18508, 108, 462]],
#  [841, [10885, 108, 10853, 11387, 462]],
#  [842, [5546, 33648, 10853, 108, 1226]],
#  [843, [20053, 34284, 15280, 108, 1226]],
#  [844, [10980, 83, 11387, 462, 1226]],
#  [845, [39247, 5154, 11387, 10884, 1226]],
#  [846, [44039, 39781, 39780, 1226, 6945]],
#  [847, [11102, 27675, 5182, 108, 462]],
#  [848, [26896, 2560, 718, 108, 1226]],
#  [849, [3909, 11052, 8732, 108, 1226]],
#  [850, [2658, 35926, 41000, 108, 1226]],
#  [851, [20586, 11890, 18536, 11052, 1226]],
#  [852, [3909, 18508, 39899, 108, 1226]],
#  [853, [11387, 5547, 8965, 462, 1226]],
#  [854, [5565, 20586, 15794, 108, 1226]],
#  [855, [36429, 11890, 11387, 108, 1226]],
#  [856, [11387, 5547, 24504, 8965, 1226]],
#  [857, [11102, 108, 15280, 11890, 1226]],
#  [858, [4753, 11387, 5154, 8965, 1226]],
#  [859, [16247, 26896, 108, 18506, 1226]],
#  [860, [5154, 11102, 10650, 108, 462]],
#  [861, [11387, 11102, 8965, 34284, 1226]],
#  [862, [4753, 11387, 10853, 1226, 8965]],
#  [863, [19761, 43159, 10884, 108, 462]],
#  [864, [36829, 18506, 10884, 108, 1226]],
#  [865, [11102, 33648, 37110, 108, 1226]],
#  [866, [43159, 5565, 15794, 108, 462]],
#  [867, [28081, 25062, 19761, 108, 1226]],
#  [868, [39899, 38378, 5356, 108, 1226]],
#  [869, [43427, 10885, 20586, 11387, 1226]],
#  [870, [43427, 11387, 20586, 29844, 1226]],
#  [871, [18508, 5154, 39780, 108, 1226]],
#  [872, [108, 5565, 8965, 26896, 462]],
#  [873, [10885, 43427, 11387, 4753, 1226]],
#  [874, [108, 11387, 36429, 10885, 1226]],
#  [875, [29844, 18536, 1180, 1226, 6945]],
#  [876, [10939, 36829, 44039, 108, 1226]],
#  [877, [41238, 5154, 41000, 108, 1226]],
#  [878, [29844, 19761, 29044, 108, 1226]],
#  [879, [10884, 24504, 5547, 108, 1226]],
#  [880, [10884, 108, 5547, 8965, 1226]],
#  [881, [12936, 26896, 36429, 108, 462]],
#  [882, [24504, 2658, 35926, 108, 462]],
#  [883, [28241, 24504, 10939, 108, 1226]],
#  [884, [41238, 10980, 18536, 1226, 6945]],
#  [885, [33751, 10884, 39781, 462, 1226]],
#  [886, [11890, 20586, 11101, 15280, 462]],
#  [887, [15280, 10885, 28081, 108, 1226]],
#  [888, [4753, 43640, 41238, 108, 1226]],
#  [889, [4753, 39899, 11387, 108, 1226]],
#  [890, [29234, 83, 11449, 108, 1226]],
#  [891, [39247, 18508, 18506, 108, 1226]],
#  [892, [10884, 5154, 18508, 108, 1226]],
#  [893, [18506, 18508, 11387, 108, 1226]],
#  [894, [10885, 5547, 44039, 108, 462]],
#  [895, [10980, 16247, 18536, 108, 1226]],
#  [896, [108, 10885, 5547, 10800, 1226]],
#  [897, [24504, 108, 8965, 11890, 1226]],
#  [898, [27675, 10885, 39780, 108, 1226]],
#  [899, [5547, 44039, 11387, 108, 1226]],
#  [900, [30657, 18506, 27362, 108, 1226]],
#  [901, [5154, 5182, 34284, 108, 462]],
#  [902, [16247, 40661, 5547, 108, 1226]],
#  [903, [15350, 5356, 24504, 108, 1226]],
#  [904, [12900, 10884, 83, 108, 1226]],
#  [905, [5565, 11049, 10884, 108, 1226]],
#  [906, [10885, 15794, 20586, 462, 1226]],
#  [907, [36429, 41000, 15794, 108, 1226]],
#  [908, [10884, 18508, 26896, 108, 1226]],
#  [909, [108, 24504, 11102, 18508, 1226]],
#  [910, [43427, 28074, 38378, 108, 1226]],
#  [911, [43427, 10853, 15350, 108, 1226]],
#  [912, [39781, 39780, 5565, 108, 462]],
#  [913, [11387, 1226, 11890, 10885, 39780]],
#  [914, [39781, 5547, 29844, 108, 1226]],
#  [915, [39247, 18506, 18508, 108, 1226]],
#  [916, [4753, 8965, 26896, 108, 1226]],
#  [917, [15280, 2658, 2560, 108, 1226]],
#  [918, [8732, 30657, 34457, 108, 1226]],
#  [919, [20586, 19761, 9010, 108, 1226]],
#  [920, [5562, 10980, 20313, 108, 1226]],
#  [921, [24504, 11052, 5356, 108, 1226]],
#  [922, [10853, 11890, 43427, 108, 462]],
#  [923, [3909, 108, 20586, 5546, 1226]],
#  [924, [10885, 108, 11101, 10884, 462]],
#  [925, [5547, 43427, 26896, 108, 1226]],
#  [926, [41707, 10885, 11387, 108, 462]],
#  [927, [26896, 11102, 41238, 108, 1226]],
#  [928, [11101, 10853, 31888, 108, 1226]],
#  [929, [11890, 15280, 36429, 108, 462]],
#  [930, [18536, 28081, 5562, 108, 1226]],
#  [931, [15280, 12936, 10885, 108, 1226]],
#  [932, [18506, 11387, 10884, 1226, 6945]],
#  [933, [11890, 15280, 36429, 108, 462]],
#  [934, [43427, 108, 11387, 29844, 1226]],
#  [935, [10884, 10853, 6545, 108, 1226]],
#  [936, [27675, 18535, 20310, 108, 462]],
#  [937, [11101, 10885, 15280, 108, 1226]],
#  [938, [11387, 108, 18508, 40661, 1226]],
#  [939, [10885, 33751, 12900, 108, 1226]],
#  [940, [10885, 11387, 4753, 44039, 1226]],
#  [941, [18536, 11890, 41000, 108, 1226]],
#  [942, [11048, 5565, 28081, 108, 1226]],
#  [943, [24504, 28081, 11890, 108, 462]],
#  [944, [11387, 10885, 5547, 108, 462]],
#  [945, [10980, 1180, 4753, 108, 1226]],
#  [946, [5562, 10853, 43427, 108, 1226]],
#  [947, [11890, 16247, 9827, 108, 462]],
#  [948, [29844, 5547, 15794, 108, 1226]],
#  [949, [8732, 18536, 20586, 108, 462]],
#  [950, [108, 11387, 5154, 8965, 462]],
#  [951, [24504, 1226, 39781, 39780, 18508]],
#  [952, [39780, 39781, 16247, 108, 1226]],
#  [953, [11387, 1226, 24504, 36429, 4753]],
#  [954, [5565, 20586, 11890, 10853, 1226]],
#  [955, [16994, 5565, 28081, 108, 1226]],
#  [956, [10885, 18536, 26896, 108, 1226]],
#  [957, [20586, 5565, 108, 8965, 1226]],
#  [958, [20586, 11102, 11387, 108, 1226]],
#  [959, [41000, 39781, 39780, 108, 1226]],
#  [960, [11052, 24504, 11730, 108, 1226]],
#  [961, [5154, 26896, 5565, 108, 462]],
#  [962, [19761, 11387, 28241, 108, 462]],
#  [963, [2165, 1180, 44039, 108, 1226]],
#  [964, [43427, 11387, 8965, 108, 462]],
#  [965, [11387, 15280, 10885, 11890, 1226]],
#  [966, [108, 10884, 4753, 8965, 1226]],
#  [967, [43427, 10939, 26896, 108, 1226]],
#  [968, [3909, 5546, 18508, 108, 462]],
#  [969, [18506, 18508, 10885, 1226, 6945]],
#  [970, [11387, 5565, 8965, 108, 1226]],
#  [971, [20586, 44039, 28081, 108, 1226]],
#  [972, [5154, 19761, 4753, 1226, 6945]],
#  [973, [108, 20586, 11387, 10885, 1226]],
#  [974, [4753, 18506, 8965, 29844, 1226]],
#  [975, [44039, 5565, 39780, 108, 1226]],
#  [976, [5154, 39780, 39781, 108, 1226]],
#  [977, [10885, 5356, 108, 20586, 462]],
#  [978, [10884, 108, 11387, 20586, 462]],
#  [979, [20313, 11890, 10853, 108, 462]],
#  [980, [10939, 19761, 18506, 108, 1226]],
#  [981, [11102, 1180, 29044, 108, 1226]],
#  [982, [11049, 5565, 11101, 108, 462]],
#  [983, [4753, 5154, 10884, 108, 462]],
#  [984, [43427, 10885, 11730, 108, 1226]],
#  [985, [43427, 108, 11387, 11101, 1226]],
#  [986, [11387, 10853, 36429, 108, 1226]],
#  [987, [10853, 11102, 8965, 462, 1226]],
#  [988, [108, 10884, 11387, 8965, 1226]],
#  [989, [11052, 32108, 16247, 108, 1226]],
#  [990, [2560, 18508, 26894, 108, 1226]],
#  [991, [20586, 10884, 11102, 1226, 1180]],
#  [992, [43427, 10884, 11890, 108, 1226]],
#  [993, [108, 10885, 39781, 39780, 1226]],
#  [994, [11052, 3909, 8732, 108, 1226]],
#  [995, [16247, 19841, 462, 29844, 40661]],
#  [996, [39781, 10885, 15794, 41000, 1226]],
#  [997, [83, 43427, 11730, 41238, 1226]],
#  [998, [28081, 26894, 2560, 108, 1226]],
#  [999, [26896, 11049, 9827, 108, 462]],
#  [1000, [5154, 8965, 18506, 11102, 462]],
#  ...]

# %% [markdown]
# ## 3. Evaluation

# %% [markdown]
# NDCG

# %% [markdown]
# Hit Ratio

# %%
sc.stop()
